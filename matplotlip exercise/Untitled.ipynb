# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

# %%
hatches = ['/', '\\', 'x', 'o']
plt.pie(exp_vals,labels=exp_labels, startangle=45, explode =[0,0,0,0,0.5],autopct='%1.1f%%', hatch=hatches)
plt.legend(loc="best")
plt.show()
